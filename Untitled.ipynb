# %%
import io
import json                    
import base64                  
import logging             
import numpy as np
from PIL import Image
import cv2
import pytesseract
import argparse
import os
import ipywidgets as widgets
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from IPython.display import display

from flask import Flask, request, jsonify, abort
plt.rcParams["figure.figsize"] = (16,9)

# %%
def getName():
    return '{}.png'.format(datetime.now().strftime('%y%m%d%H%M%S%f'))

# %%
a = widgets.IntSlider(value=11, min=5, max=35)
b = widgets.IntSlider(value=2, min=1, max=16)
display(a)
display(b)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may help.
# Widget Javascript not detected.  It may not be installed or enabled properly. Reconnecting the current kernel may help.

# %%
origin_file_name = '220825165145679597.png'

image = cv2.imread(origin_file_name)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

gray = cv2.adaptiveThreshold(gray, 255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,a.value,b.value)
plt.imshow(gray, cmap='binary_r')
plt.title('my picture')
plt.show()
